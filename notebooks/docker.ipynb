# %%
import pandas as pd

# %%
df = pd.read_csv('/home/mohammad/RenewableInsight/data/docker_stats.csv')

# %%
df.head(10)
# Out:
#                      Container ID                      Name      CPU %  \
# 2024-07-22 19:21:36  4c9ffbfb03ce       kafka_producer_load   0.251678
# 2024-07-22 19:21:36  25415565ccb8  renewableinsight-magic-1  11.141568
# 2024-07-22 19:21:36  dec0b31631ee            control-center   4.351400
# 2024-07-22 19:21:36  19299490dbfa                    broker   1.956797
# 2024-07-22 19:21:36  f7a9623ccd18                 zookeeper   0.145013
# 2024-07-22 19:21:51  4c9ffbfb03ce       kafka_producer_load   0.253204
# 2024-07-22 19:21:51  25415565ccb8  renewableinsight-magic-1  11.190037
# 2024-07-22 19:21:51  dec0b31631ee            control-center   3.646567
# 2024-07-22 19:21:51  19299490dbfa                    broker   2.909689
# 2024-07-22 19:21:51  f7a9623ccd18                 zookeeper   0.333682
#
#                      Memory Usage  Memory Limit  Memory %  Network Input  \
# 2024-07-22 19:21:36      68284416   10420965376  0.655260        1114254
# ...

# %%
df.groupby(by=["Container ID","Name"]).mean()
# Out:
#                                            CPU %  Memory Usage  Memory Limit  \
# Container ID Name
# 19299490dbfa broker                     2.721922   679891584.0  1.042097e+10
# 25415565ccb8 renewableinsight-magic-1  11.327877   686112896.0  1.042097e+10
# 4c9ffbfb03ce kafka_producer_load        0.269435    73681664.0  1.042097e+10
# dec0b31631ee control-center             4.531083   749371520.0  1.042097e+10
# f7a9623ccd18 zookeeper                  0.998147   183123072.0  1.042097e+10
#
#                                        Memory %  Network Input  \
# Container ID Name
# 19299490dbfa broker                    6.524267   5.240047e+07
# 25415565ccb8 renewableinsight-magic-1  6.583967   5.589147e+05
# 4c9ffbfb03ce kafka_producer_load       0.707052   1.400178e+06
# dec0b31631ee control-center            7.190999   6.504996e+07
# f7a9623ccd18 zookeeper                 1.757256   1.022804e+06
#
#                                        Network Output  Block Input  \
# ...
